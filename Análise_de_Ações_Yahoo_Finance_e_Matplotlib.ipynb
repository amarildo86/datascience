# %% [markdown]
# <a href="https://colab.research.google.com/github/amarildo86/datascience/blob/master/An%C3%A1lise_de_A%C3%A7%C3%B5es_Yahoo_Finance_e_Matplotlib.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import pandas_datareader as pdr
import datetime
import matplotlib.pyplot as plt

# %%
inicio = datetime.datetime(2019, 1, 1)
fim = datetime.datetime(2021, 1, 1)

tickers = ['PETR4.SA', 'VALE3.SA', 'ITUB3.SA', 'BBDC3.SA', 'MGLU3.SA', 'VVAR3.SA']

df = pdr.DataReader(tickers, 'yahoo', inicio, fim)

# %%
plt.figure(figsize=(18, 7.5))
plt.ylabel('Peço de Fechamento em R$')
plt.plot(df['Adj Close'])
plt.legend(tickers)
