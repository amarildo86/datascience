# %% [markdown]
# <a href="https://colab.research.google.com/github/amarildo86/datascience/blob/master/Matplotlib.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier

# %%
iris = load_iris()
X = iris['data']
y = iris['target']

# %%
sns.boxplot(data=iris['data'])

# %%
X_train, X_test, y_train, y_test = train_test_split(
    iris['data'], iris['target'], random_state=0)

# %%
print('\nBase de treinamento ({0}): \n{1}\n'.format('X_train.shape', X_train.shape))
print('\nBase de teste ({0}): \n{1}\n'.format('X_test.shape', X_test.shape))
# Out:
# Base de treinamento (X_train.shape):
# (112, 4)
#
#
# Base de teste (X_test.shape):
# (38, 4)
